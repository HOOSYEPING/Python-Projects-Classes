# %%
#Practice Exercise: Extracting State Population
import requests
api_url="https://jian.sh/malaysia-api/state/v1/all.json"
response = requests.get(api_url)
malaysia_state_data=response.json()

user_input=input("Enter the name of a state :")

for state in malaysia_state_data:
    if state['state'].lower()==user_input.lower():
        print (f"Population of {user_input} :{state['population']}") #to print answer that related to previous input data use{}
        break
        
else:
    print (f"State '{user_input}' not found in the data.")
# Out:
# Enter the name of a state :Johor
# Population of Johor :3794000

# %%
#Exercise 1： Processing Student Data with Python

#Read csv file
import csv
with open('copy of students.csv','r')as file:
    csv_reader=csv.reader(file)
    for row in csv_reader:
        print(row)
# Out:
# ['Name', 'Age', 'Grade']
# ['Alice', '21', 'A']
# ['Bob', '22', 'F']
# ['Charlie', '18', 'B']
# ['David', '21', 'A']
# ['Eve', '20', 'A']
# ['Fiona', '18', 'C']
# ['George', '19', 'A']
# ['Hannah', '20', 'C']
# ['Isla', '22', 'A']
# ['Jack', '21', 'B']
# ['Alice', '20', 'C']
# ['Bob', '20', 'C']
# ['Charlie', '18', 'C']
# ['David', '20', 'A']
# ['Eve', '21', 'B']
# ['Fiona', '19', 'C']
# ['George', '18', 'F']
# ['Hannah', '19', 'B']
# ['Isla', '19', 'B']
# ['Jack', '18', 'F']
# ['Alice', '18', 'F']
# ['Bob', '18', 'F']
# ['Charlie', '18', 'C']
# ['David', '18', 'F']
# ['Eve', '20', 'B']
# ['Fiona', '19', 'B']
# ['George', '21', 'D']
# ['Hannah', '19', 'B']
# ['Isla', '19', 'B']
# ['Jack', '18', 'F']
# ['Alice', '19', 'B']
# ['Bob', '20', 'B']
# ['Charlie', '22', 'D']
# ['David', '20', 'C']
# ['Eve', '19', 'A']
# ['Fiona', '20', 'F']
# ['George', '21', 'F']
# ['Hannah', '22', 'F']
# ['Isla', '21', 'F']
# ['Jack', '19', 'F']
# ['Alice', '20', 'C']
# ['Bob', '22', 'F']
# ...

# %%
#Filter Data: Filter out studnets who have a grade less than 'B'.
import csv 

input_csv_file = 'copy of students.csv'
output_csv_file = 'top_students.csv'
filtered_criteria = ['A', 'B']

filtered_rows = []

with open(input_csv_file, 'r') as file:
    csv_reader = csv.DictReader(file)
    for row in csv_reader:
        if row['Grade'] in filtered_criteria:
            row['Status']='Passed'
            filtered_rows.append([row['Name'],row['Grade'],row['Status']])
           
with open(output_csv_file, 'w', newline="") as file:
    writer = csv.writer(file)
    writer.writerow(['Name','Grade','Status'])
    writer.writerows(filtered_rows)
